# %%
import uproot

# %%
filter_name = [
    "showers_size", 
    "showers_nDigis", 
    # "showers_nShowers", 
    # "realshowers_nDigis",
    "realshowers_type", 
    "showered_genmuon_meth", 
    "shower_tpfptnfn",
    # "showers_classification",
    "shower_filter_highpt_tag_eff"
]

# %%
G_org = uproot.open("histograms_zp_H.root")

# %%
filtered_histos = {}
for key in G_org.keys():
    if any([f in key for f in filter_name]):
        filtered_histos[key.replace(";1", "")] = G_org[key]

# %%
filter_name = [
    "realshowers_nDigis",
    # "shower_filter_highpt_tag_eff"
]

# %%
G_news = uproot.open("histograms_zp_2H.root")

# %%
filtered_histos_Gnews = {}
for key in G_news.keys():
    if any([f in key for f in filter_name]):
        filtered_histos_Gnews[key.replace(";1", "")] = G_news[key]

# %%
filter_name = [
    "showers_classification",
]

# %%
G_news2 = uproot.open("histograms_zp_I.root")

# %%
filtered_histos_Gnews2 = {}
for key in G_news2.keys():
    if any([f in key for f in filter_name]):
        filtered_histos_Gnews2[key.replace(";1", "")] = G_news2[key]

# %%
filter_name = [
    "nShowers",
]

# %%
filtered_histos_Gnews3 = {}
for key in G_org.keys():
    if any([f in key for f in filter_name]):
        filtered_histos_Gnews3["showers_" + key.replace(";1", "")] = G_org[key]

# %%
with uproot.recreate("../histograms_zp_H.root") as f:
    for key, histo in filtered_histos.items():
        f[key] = histo
    for key, histo in filtered_histos_Gnews.items():
        f[key] = histo
    for key, histo in filtered_histos_Gnews2.items():
        f[key] = histo
    for key, histo in filtered_histos_Gnews3.items():
        f[key] = histo
